# %% [markdown]
# ---
# layout: default
# title: Developing_ProceduresPY Homework
# description: This is Akhil's homework/hacks for the Developing Procedures lesson for Python
# categories: ['Lessons']
# permalink: /github/pages/Developing_ProceduresPY_HW
# breadcrumb: True
# ---

# %% [markdown]
# <div align="center" style="margin-bottom: 2em;">
#   <a href="{{ site.baseurl }}/csp/big-idea-three/developingprocedures/lesson/p3/syntaxterrors"
#      style="
#       display: inline-block;
#       background: linear-gradient(90deg, #2563eb 0%, #1e40af 100%);
#       color: white;
#       padding: 0.85em 2.2em;
#       border-radius: 0.6em;
#       font-weight: bold;
#       text-decoration: none;
#       font-size: 1.15em;
#       box-shadow: 0 4px 16px rgba(30,64,175,0.18), 0 1.5px 4px rgba(0,0,0,0.10);
#       transition:
#         background 0.2s,
#         transform 0.15s,
#         box-shadow 0.2s;
#     "
#     onmouseover="this.style.transform='scale(1.045)'; this.style.boxShadow='0 8px 24px rgba(30,64,175,0.22), 0 2px 8px rgba(0,0,0,0.13)';"
#     onmouseout="this.style.transform='scale(1)'; this.style.boxShadow='0 4px 16px rgba(30,64,175,0.18), 0 1.5px 4px rgba(0,0,0,0.10)';"
#   >
#     Developing Procedures Lesson
#   </a>
# </div>

# %% [markdown]
# ## Practice Developing Procedures
# In these examples, you'll be practicing developing procedures based off the context of the name and the call.
#
# Practice 1:

# %%
def add(a, b):
    return a + b  # ✅ Return the sum so it can be used later too

def show_sum(a, b):
    total = add(a, b)
    print("The sum is:", total)

show_sum(4, 7)
# My code defines a simple addition procedure and a display procedure.
# Out:
# The sum is: 11

# %% [markdown]
# Practice 2:

# %%
# Enhanced morning routine with repeat parameter
def morning_routine(repeat=1):
    """
    Executes the main morning tasks in order.
    
    Parameters:
    repeat (int): How many times to perform each activity.
    """
    tasks = ["Wake up!", "Eat breakfast!", "Get ready for the day!", "Go to school!"]
    
    for i in range(repeat):
        print(f"--- Morning round {i + 1} ---")
        for task in tasks:
            print(task)

# Run the morning routine once
morning_routine(1)

print("\n")  # Just for spacing

# Run the morning routine twice
morning_routine(2)
# After combining the tasks into a single procedure, I added a 'repeat' parameter to allow multiple rounds of the routine.
# Out:
# --- Morning round 1 ---
# Wake up!
# Eat breakfast!
# Get ready for the day!
# Go to school!
#
#
# --- Morning round 1 ---
# Wake up!
# Eat breakfast!
# Get ready for the day!
# Go to school!
# --- Morning round 2 ---
# Wake up!
# Eat breakfast!
# Get ready for the day!
# Go to school!

# %% [markdown]
# Practice 3:

# %%
# Function that greets a given name parameter
def greet(name):
    print(f"Hi {name}!")

# Test different inputs
greet("Mr. Mort")
greet("Akhil")
greet("Bob")
# Out:
# Hi Mr. Mort!
# Hi Akhil!
# Hi Bob!

# %% [markdown]
# ## Combining Calling and Developing Procedures
# Now that you understand both calling and developing, let's combine the two to fully use functions!
# Your final task is to be able to produce, on your own, three procedures and call them in an order that makes sense. For example:

# %%
def get_grades():
    grades = [87, 93, 88, 91, 90]
    return grades


def grade_calc(grades):
    total = sum(grades)
    average = total / len(grades)
    return average

def display_grade():
    grades = get_grades()
    average = grade_calc(grades)
    print ("Your final average grade is:", average)

display_grade()
# Out:
# Your final average grade is: 89.8

# %% [markdown]
# The requirements for this are:
# 1. must have three seperate procedures.
# 2. must call all three procedures at least once, and it can be within other procedures.
# 3. must have at least one print and at least one math function.
# 4. at least one procedure must have multiple steps.
#
# Other than that, have fun and create something as simple or complex as you'd like!

# %%
# Procedure: List the exercises for the day
def get_exercises():
    """
    Returns a list of exercises for today's workout.
    """
    exercises = ["Push-ups", "Sit-ups", "Squats", "Jumping jacks"]
    return exercises

# Procedure: Calculate total reps for the exercises
def total_reps(exercises):
    """
    Calculates total reps for the workout.
    Each exercise has a different number of reps.
    """
    reps_per_exercise = {"Push-ups": 15, "Sit-ups": 20, "Squats": 25, "Jumping jacks": 30}
    total = 0
    for exercise in exercises:
        reps = reps_per_exercise.get(exercise, 0)
        print(f"Doing {reps} reps of {exercise}")  # Multiple steps
        total += reps
    return total

# Procedure: Display the workout summary
def display_workout_summary():
    """
    Runs the morning workout routine and prints the summary.
    """
    exercises = get_exercises()               # Call procedure 1
    total = total_reps(exercises)             # Call procedure 2
    average = total / len(exercises)          # Math function to calculate average reps
    print(f"\nToday's total reps: {total}")
    print(f"Average reps per exercise: {average:.1f}")

# Execute the workout
display_workout_summary()
# Out:
# Doing 15 reps of Push-ups
# Doing 20 reps of Sit-ups
# Doing 25 reps of Squats
# Doing 30 reps of Jumping jacks
#
# Today's total reps: 90
# Average reps per exercise: 22.5
