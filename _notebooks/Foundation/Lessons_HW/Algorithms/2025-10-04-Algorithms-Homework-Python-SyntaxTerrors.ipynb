# %%
---
layout: default
title: AlgorithmsPY Homework
description: This is Akhil's homework/hacks for the Algorithms lesson for Python
categories: ['Lessons']
permalink: /github/pages/AlgorithmsPY_HW
breadcrumb: True
---

# %% [markdown]
# <div align="center" style="margin-bottom: 2em;">
#   <a href="{{ site.baseurl }}/csp/big-idea-three/algorithms/lesson/p3/syntaxterrors"
#      style="
#       display: inline-block;
#       background: linear-gradient(90deg, #2563eb 0%, #1e40af 100%);
#       color: white;
#       padding: 0.85em 2.2em;
#       border-radius: 0.6em;
#       font-weight: bold;
#       text-decoration: none;
#       font-size: 1.15em;
#       box-shadow: 0 4px 16px rgba(30,64,175,0.18), 0 1.5px 4px rgba(0,0,0,0.10);
#       transition:
#         background 0.2s,
#         transform 0.15s,
#         box-shadow 0.2s;
#     "
#     onmouseover="this.style.transform='scale(1.045)'; this.style.boxShadow='0 8px 24px rgba(30,64,175,0.22), 0 2px 8px rgba(0,0,0,0.13)';"
#     onmouseout="this.style.transform='scale(1)'; this.style.boxShadow='0 4px 16px rgba(30,64,175,0.18), 0 1.5px 4px rgba(0,0,0,0.10)';"
#   >
#     Algorithms Lesson
#   </a>
# </div>

# %%
# ============================================================
# AP CSP: Developing Algorithms with Tic Tac Toe 🧩
# ============================================================
# Today you'll use algorithmic thinking to model a Tic Tac Toe game!
# We'll use a 2D list to represent the board and write algorithms
# that make moves and check for a winner.
# ============================================================


# -------------------------------
# Popcorn Hack 1: Initialize the 3x3 Board
# -------------------------------
# Create a 2D list that represents a 3x3 Tic Tac Toe board.
# Each space starts as "_".

board = [
    ["_", "_", "_"],
    ["_", "_", "_"],
    ["_", "_", "_"]
]

print("Starting board:")
for row in board:
    print(row)


# -------------------------------
# Popcorn Hack 2: Make a Move
# -------------------------------
# Place an "X" in the center and an "O" in the top-left corner.

board[1][1] = "X"  # Center
board[0][0] = "O"  # Top-left

print("\nBoard after two moves:")
for row in board:
    print(row)


# -------------------------------
# Popcorn Hack 3: Check for a Win
# -------------------------------
def check_winner(board, player):
    # --- Check rows ---
    for r in range(3):
        if board[r][0] == player and board[r][1] == player and board[r][2] == player:
            return True

    # --- Check columns ---
    for c in range(3):
        if board[0][c] == player and board[1][c] == player and board[2][c] == player:
            return True

    # --- Check the first diagonal ---
    if board[0][0] == player and board[1][1] == player and board[2][2] == player:
        return True
    
    # --- Check the second diagonal ---
    if board[0][2] == player and board[1][1] == player and board[2][0] == player:
        return True

    # No winner found
    return False


# -------------------------------
# Test your algorithm
# -------------------------------
board = [
    ["X", "O", "X"],
    ["O", "X", "_"],
    ["O", "_", "X"]
]

print("\nTesting winner algorithm:")
for row in board:
    print(row)

# Check both players
if check_winner(board, "X"):
    print("X wins!")
elif check_winner(board, "O"):
    print("O wins!")
else:
    print("No winner yet.")
# Completed all homework/popcorn hacks!
# Out:
# Starting board:
# ['_', '_', '_']
# ['_', '_', '_']
# ['_', '_', '_']
#
# Board after two moves:
# ['O', '_', '_']
# ['_', 'X', '_']
# ['_', '_', '_']
#
# Testing winner algorithm:
# ['X', 'O', 'X']
# ['O', 'X', '_']
# ['O', '_', 'X']
# X wins!
